# %%
# _*_ coding=utf-8 _*_ 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys, os
from math import log, ceil
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号

# %%
df_k70 = pd.read_csv('./LT/open_test/avgs_open_k=70.csv')
df_k100 = pd.read_csv('./LT/open_test/avgs_open_k=100.csv')
df_k150 = pd.read_csv('./LT/open_test/avgs_open_k=150.csv')
df_k200 = pd.read_csv('./LT/open_test/avgs_open_k=200.csv')
df_k250 = pd.read_csv('./LT/open_test/avgs_open_k=250.csv')
df_k300 = pd.read_csv('./LT/open_test/avgs_open_k=300.csv')
df_k350 = pd.read_csv('./LT/open_test/avgs_open_k=350.csv')
df_k400 = pd.read_csv('./LT/open_test/avgs_open_k=400.csv')
df_k450 = pd.read_csv('./LT/open_test/avgs_open_k=450.csv')
df_k500 = pd.read_csv('./LT/open_test/avgs_open_k=500.csv')
a = list(df_k70['a'])
pro_70 = list(df_k70['pro'])
pro_100 = list(df_k100['pro'])
pro_150 = list(df_k150['pro'])
pro_200 = list(df_k200['pro'])
pro_250 = list(df_k250['pro'])
pro_300 = list(df_k300['pro'])
pro_350 = list(df_k350['pro'])
pro_400 = list(df_k400['pro'])
pro_450 = list(df_k450['pro'])
pro_500 = list(df_k500['pro'])
# plot
plt.plot(a, pro_70, marker='*', label='k = 70')
plt.plot(a, pro_100, marker='*', label='k = 100')
#plt.plot(a, pro_150, marker='*', label='k = 150')
#plt.plot(a, pro_200, marker='*', label='k = 200')
#plt.plot(a, pro_250, marker='*', label='k = 250')
plt.plot(a, pro_300, marker='*', label='k = 300')
#plt.plot(a, pro_350, marker='*', label='k = 350')
#plt.plot(a, pro_400, marker='*', label='k = 400')
#plt.plot(a, pro_450, marker='*', label='k = 450')
plt.plot(a, pro_500, marker='*', label='k = 500')
plt.xlabel('a')
plt.ylabel('pros')
plt.grid()
plt.legend()
plt.savefig('./report/test_open_a_K_pros.pdf')
plt.show()
